# %% [markdown]
# # NK Data
#
# For adding new nk data to my master directory
#
# initial stuff

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import interp1d

# %% [markdown]
# define plot style

# %%
# %config InlineBackend.figure_format = 'retina' #to make inline images higher res
plt.style.use(['presplot_small']) #this is a plot format that I have in my style folder on my computer

# %% [markdown]
# load nk data - as a dictionary with the different materials as items, arrays are lambda (microns), n, k

# %%
nkdata_raw = np.load('nkdata_raw.npy',allow_pickle='TRUE').item()
print(nkdata_raw.keys())
# Out:
# dict_keys(['Ag_raw', 'Al_raw', 'Au_raw', 'BCP_raw', 'C60_raw', 'Cu_raw', 'ITO_raw', 'In_raw', 'MoO_3_raw', 'MoS_2_raw', 'MoSe_2_raw', 'NiO_x_raw', 'PDMS_raw', 'PEDOT_raw', 'PTAA_raw', 'PTCDA_raw', 'Pd_raw', 'Pt_raw', 'SiO_2_raw', 'Si_raw', 'SnO_2_raw', 'Spiro_raw', 'TCTA_raw', 'TiO_2_raw', 'Ti_raw', 'WO_3_raw', 'WS_2_raw', 'WSe_2_raw', 'ZnO_raw', 'hBN_raw', 'monoWS_2_raw'])

# %% [markdown]
# edit nk data

# %%
matname='C_{60}'
filename=matname+'-Horiba.csv'

new_mat=np.genfromtxt('raw-nk/'+filename, delimiter=',', skip_header=1,usecols=(0,1,2))
#new_mat[:,0]=new_mat[:,0]*1e-3 #for data in nm
nkdata_raw[matname+'_raw']=new_mat

# %% [markdown]
# check which materials are now included

# %%
#nkdata_raw.pop('TiO_2', None) #if I added the wrong thing by mistake
print(nkdata_raw.keys())
#nkdata_raw['PTAA_raw']
# Out:
# dict_keys(['Ag_raw', 'Al_raw', 'Au_raw', 'BCP_raw', 'C60_raw', 'Cu_raw', 'ITO_raw', 'In_raw', 'MoO_3_raw', 'MoS_2_raw', 'MoSe_2_raw', 'NiO_x_raw', 'PDMS_raw', 'PEDOT_raw', 'PTAA_raw', 'PTCDA_raw', 'Pd_raw', 'Pt_raw', 'SiO_2_raw', 'Si_raw', 'SnO_2_raw', 'Spiro_raw', 'TCTA_raw', 'TiO_2_raw', 'Ti_raw', 'WO_3_raw', 'WS_2_raw', 'WSe_2_raw', 'ZnO_raw', 'hBN_raw', 'monoWS_2_raw', 'C_{60}_raw'])

# %%
def smooth(array, window_size):
    window= np.ones(int(window_size))/float(window_size)
    return np.convolve(array, window, 'same')

# %% [markdown]
# plot nk data for a given material

# %%
material='C_{60}'

fig,ax=plt.subplots()
lda=nkdata_raw[material+'_raw'][:,0]
n=nkdata_raw[material+'_raw'][:,1]
k=nkdata_raw[material+'_raw'][:,2]
#n2=smooth(nkdata_raw[material+'_raw'][:,1],5)
#k2=smooth(nkdata_raw[material+'_raw'][:,2],5)
plt.plot(lda,n,label='n')
plt.plot(lda,k,label='k')
#plt.plot(lda,n2,label='n2')
#plt.plot(lda,k2,label='k2')
ax.set_xlabel('Wavelength ($\mu$m)')
ax.set_ylabel('Index')
ax.set_xlim([0.3,0.9])
#ax.set_ylim([0,3])
ax.set_title('$'+material+'$')
ax.legend()

# %% [markdown]
# sort nk data

# %%
nkdata_raw = dict(sorted(nkdata_raw.items()))

# %% [markdown]
# save nk data

# %%
np.save('nkdata_raw.npy', nkdata_raw)

# %% [markdown]
# ### Formatting nk data for Sentaurus

# %%
matname='ITO'
temp_mat=nkdata_raw[matname+'_raw']

# %%
f=open('raw-nk/'+matname+'_sentaurus.txt','w+')

for i in np.arange(0,np.shape(temp_mat)[0],1):
    f.write('          '+str(float('%.4g' % temp_mat[i,0]))+' '+str(float('%.4g' % temp_mat[i,1]))
            +' '+str(float('%.4g' % temp_mat[i,2]))+';\n')
    
    i+=1
f.close()

# %% [markdown]
# AM1.5

# %%
am1p5_raw=np.loadtxt('am1p5.txt')

# %%
f=open('am1p5_sentaurus.txt','w+')
f.write('wavelength [nm] intensity [W*m^-2]\n')

for i in np.arange(0,np.shape(am1p5_raw)[0],1):
    f.write('+'+str(float('%.4g' % am1p5_raw[i,0]))+' +'+str(float('%.4g' % am1p5_raw[i,1]))+'\n')
    
    i+=1
f.close()

# %% [markdown]
# ### Old: converting from .mat to .npy

# %% [markdown]
# load nk data - as a dictionary with the different materials as items, arrays are lambda (microns), n, k

# %% [markdown]
# nkdata_raw = scipy.io.loadmat('nkdata.mat')
# print(nkdata_raw.keys())

# %% [markdown]
# remove entries that aren't relevant

# %% [markdown]
# nkdata_raw.pop('__header__', None)
# nkdata_raw.pop('__version__', None)
# nkdata_raw.pop('__globals__', None)
# print(nkdata_raw.keys())

# %% [markdown]
# save as numpy file

# %% [markdown]
# #Save
# np.save('nkdata_raw.npy', nkdata_raw)
#
# #Load
# test = np.load('nkdata_raw.npy',allow_pickle='TRUE').item()
